# %%
import matplotlib.pyplot as plt
empl_count=[3,68,4,95,2,1]
year=[2014,2015,2016,2017,2018,2019]
plt.plot(year,empl_count)
plt.show()

# %%
import matplotlib.pyplot as plt
empl_count=[3,68,4,95,2,1]
year=[2014,2015,2016,2017,2018,2019]
plt.plot(year,empl_count,'*--g')
plt.xlabel('year')
plt.ylabel('employees')
plt.title('employee growth at xyz')
plt.show()

# %%
import matplotlib.pyplot as plt
sub=['python','java','dbms','cn']
students=[40,30,20,50]
plt.bar(sub,students)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
sports=['kabbaddi','football','chess','vallybal','cricket']
students=[40,30,20,50,26]
plt.pie(students,labels=sports,autopct=' %1.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,5,2,6,8,5,4,7,3,5,8,4,9,5,77,26,14,57,26,34,68,28,34,67,69,18,5]
plt.hist(x)
plt.xlabel('age')
plt.ylabel('count')
plt.title('population')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,5,2,6,8,5]
y=[8,8.5,9.5,10,10.5,11]
plt.scatter(x,y,label='values of x&y ',color='r')
plt.title('smart band data report')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
